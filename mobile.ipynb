# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ml=pd.read_csv('/content/drive/MyDrive/data set/mobile_sales_data.csv')
ml
# Out:
#             Product      Brand Product Code  \
# 0      Mobile Phone   Motorola     88EB4558
# 1            Laptop       Oppo     416DFEEB
# 2      Mobile Phone    Samsung     9F975B08
# 3            Laptop       Sony     73D2A7CC
# 4            Laptop  Microsoft     CCE0B80D
# ...             ...        ...          ...
# 49995        Laptop   Motorola     8C187637
# 49996        Laptop         HP     0DA9E4D3
# 49997        Laptop    Toshiba     CAD89A93
# 49998  Mobile Phone     Lenovo     78566C17
# 49999        Laptop       Asus     9C3FC57C
#
#                                    Product Specification   Price Inward Date  \
# 0      Site candidate activity company there bit insi...   78570  2023-08-02
# 1                Beat put care fight affect address his.   44613  2023-10-03
# 2               Energy special low seven place audience.  159826  2025-03-19
# 3      Friend record hard contain minute we role sea ...   20911  2024-02-06
# ...

# %%
ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product                  50000 non-null  object
#  1   Brand                    50000 non-null  object
#  2   Product Code             50000 non-null  object
#  3   Product Specification    50000 non-null  object
#  4   Price                    50000 non-null  int64
#  5   Inward Date              50000 non-null  object
#  6   Dispatch Date            50000 non-null  object
#  7   Quantity Sold            50000 non-null  int64
#  8   Customer Name            50000 non-null  object
#  9   Customer Location        50000 non-null  object
#  10  Region                   50000 non-null  object
#  11  Core Specification       25017 non-null  object
#  12  Processor Specification  50000 non-null  object
#  13  RAM                      50000 non-null  object
# ...

# %% [markdown]
# remove unwanted column

# %%
ml.drop(['Core Specification','Product Specification','Inward Date','Dispatch Date','Region'],axis=1,inplace=True)

# %%
ml
# Out:
#             Product      Brand Product Code   Price  Quantity Sold  \
# 0      Mobile Phone   Motorola     88EB4558   78570              6
# 1            Laptop       Oppo     416DFEEB   44613              1
# 2      Mobile Phone    Samsung     9F975B08  159826              5
# 3            Laptop       Sony     73D2A7CC   20911              1
# 4            Laptop  Microsoft     CCE0B80D   69832              4
# ...             ...        ...          ...     ...            ...
# 49995        Laptop   Motorola     8C187637  170385              6
# 49996        Laptop         HP     0DA9E4D3  193133              4
# 49997        Laptop    Toshiba     CAD89A93   66502              6
# 49998  Mobile Phone     Lenovo     78566C17  158883              2
# 49999        Laptop       Asus     9C3FC57C   86483              7
#
#            Customer Name      Customer Location Processor Specification   RAM  \
# 0           William Hess           South Kelsey        Snapdragon 7 Gen  12GB
# ...

# %% [markdown]
# fill 0 i SSD column for NaN values

# %%
ml['SSD'].fillna(0,inplace=True)
ml
# Out:
# /tmp/ipython-input-1726072731.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ml['SSD'].fillna(0,inplace=True)
#             Product      Brand Product Code   Price  Quantity Sold  \
# 0      Mobile Phone   Motorola     88EB4558   78570              6
# 1            Laptop       Oppo     416DFEEB   44613              1
# 2      Mobile Phone    Samsung     9F975B08  159826              5
# 3            Laptop       Sony     73D2A7CC   20911              1
# ...

# %%
ml[ml['Product']=='Laptop'].max()
# Out:
# Product                          Laptop
# Brand                              iQOO
# Product Code                   FFFE5D40
# Price                            199997
# Quantity Sold                        10
# Customer Name              Zoe Phillips
# Customer Location           Zunigaville
# Processor Specification              i9
# RAM                                 8GB
# ROM                                64GB
# SSD                               512GB
# dtype: object

# %%
ml[(ml['Brand']=='iQOO')&(ml['Product']=='Laptop')]
# Out:
#       Product Brand Product Code   Price  Quantity Sold  \
# 20     Laptop  iQOO     651469C2  168076              8
# 26     Laptop  iQOO     37D3F7F4   87053              2
# 52     Laptop  iQOO     F5B6B3D7  165298              8
# 68     Laptop  iQOO     D4B363CC   11902              8
# 80     Laptop  iQOO     02F432C7   98945              9
# ...       ...   ...          ...     ...            ...
# 49769  Laptop  iQOO     F6F643E9  143781              9
# 49794  Laptop  iQOO     0D387137   66027              1
# 49885  Laptop  iQOO     3C11850D  165618              1
# 49907  Laptop  iQOO     36FD37BC  162768              1
# 49914  Laptop  iQOO     7ECAB68D  122504              2
#
#                Customer Name   Customer Location Processor Specification  \
# 20          Mr. James Harris            Rayville                      i5
# 26             Dennis Taylor            Paulport                      i7
# ...

# %%
ml['Customer Location'].unique()
# Out:
# array(['South Kelsey', 'North Lisa', 'South Todd', ...,
#        'West Christineview', 'New Dennisview', 'Huntfurt'], dtype=object)

# %% [markdown]
# to find highest customer location

# %%
ml['Customer Location'].value_counts()
# Out:
# Customer Location
# South Michael       54
# North Michael       40
# East Michael        39
# New James           39
# New Michael         38
#                     ..
# Dominguezbury        1
# South Debratown      1
# West Melaniefort     1
# Blanchardton         1
# New Kyletown         1
# Name: count, Length: 25147, dtype: int64

# %% [markdown]
# laptop selling on heighst customer location

# %%
ml[(ml['Customer Location']=='South Michael')&(ml['Product']=='Laptop')]
# Out:
#       Product      Brand Product Code   Price  Quantity Sold  \
# 907    Laptop       Acer     473128A5   13015              6
# 2883   Laptop  Microsoft     506851A7   59601              8
# 4198   Laptop    Samsung     F282A451  179139              9
# 6766   Laptop  Microsoft     8D702945  196584              1
# 9817   Laptop     Lenovo     301CDB7A  159380              1
# 10105  Laptop       Sony     A7F1725F  141131              9
# 10207  Laptop   Motorola     C6DCCE37    8664              2
# 10742  Laptop     Huawei     B97692BE  143387             10
# 11232  Laptop    OnePlus     98F7F389   16839             10
# 11454  Laptop       Acer     6E8553DF   89151              6
# 11960  Laptop       Sony     8A11F358  147910              1
# 12566  Laptop   Motorola     7CA464B2   84111              1
# 14632  Laptop       Dell     08F571DF  193799              2
# 21897  Laptop    Samsung     847A8691  115588              5
# ...

# %% [markdown]
# mobile phone selling on heighst customer location

# %%
ml[(ml['Customer Location']=='South Michael')&(ml['Product']=='Mobile Phone')]
# Out:
#             Product      Brand Product Code   Price  Quantity Sold  \
# 5681   Mobile Phone       iQOO     10E4639E   36812              9
# 7526   Mobile Phone  Microsoft     992D304F   89170              2
# 7980   Mobile Phone    OnePlus     8C08B0F2  193043              3
# 8750   Mobile Phone     Google     E2EAB403   77241              1
# 13256  Mobile Phone    Samsung     864A9178   30294             10
# 16616  Mobile Phone     Lenovo     7ECE2EBB  144266              4
# 19081  Mobile Phone    Toshiba     DC0A1012  147045              1
# 19451  Mobile Phone       Vivo     E9765472   20225              4
# 26832  Mobile Phone       Oppo     94AF3525   11952              7
# 28451  Mobile Phone         HP     08CBDDB8   70089              2
# 28676  Mobile Phone       iQOO     B766BA1D   45973              5
# 30079  Mobile Phone      Nokia     C6220C73   70525              8
# 30498  Mobile Phone      Apple     F83F033A   95248              8
# ...

# %% [markdown]
# to find most selling in brands

# %%
ml['Brand'].value_counts()
# Out:
# Brand
# Google       2598
# Nokia        2571
# Apple        2564
# Samsung      2558
# Toshiba      2555
# Sony         2547
# OnePlus      2541
# Acer         2533
# Redmi        2529
# Huawei       2497
# Vivo         2489
# Motorola     2483
# Lenovo       2471
# iQOO         2467
# Oppo         2460
# Microsoft    2457
# HP           2446
# Dell         2435
# Asus         2413
# Realme       2386
# Name: count, dtype: int64

# %% [markdown]
# find some important data for top 5 mobile brand

# %%
ml.describe()
# Out:
#                Price  Quantity Sold
# count   50000.000000    50000.00000
# mean   102641.407080        5.51378
# std     56363.550361        2.88101
# min      5008.000000        1.00000
# 25%     53487.000000        3.00000
# 50%    103072.000000        6.00000
# 75%    151396.250000        8.00000
# max    199999.000000       10.00000

# %%
ms=ml[(ml['Brand'].isin(['Google','Nokia','Apple','Samsung','Toshiba']))&(ml['Product']=='Mobile Phone')][['Product','Brand','Price','Quantity Sold','Processor Specification','RAM','ROM']]

# %%
ms1=['Google','Nokia','Apple','Samsung','Toshiba']
p1=np.arange(len(ms1))
p=[j for j in ms1]
p
# Out:
# ['Google', 'Nokia', 'Apple', 'Samsung', 'Toshiba']

# %% [markdown]
# find some important data for top 5 Laptop brand

# %%
mb=ml[(ml['Brand'].isin(['Google','Nokia','Apple','Samsung','Toshiba']))&(ml['Product']=='Laptop')][['Product','Brand','Price','Quantity Sold','Processor Specification','RAM','ROM','SSD']]

# %%
mb
# Out:
#       Product    Brand   Price  Quantity Sold Processor Specification   RAM  \
# 7      Laptop    Apple   15041              1                      i7  12GB
# 8      Laptop    Apple  186647              3                      i5  16GB
# 13     Laptop    Nokia  195641             10                 Ryzen 3  12GB
# 23     Laptop    Nokia   55049              9                 Ryzen 3   8GB
# 28     Laptop  Samsung  133951              2                 Ryzen 3  16GB
# ...       ...      ...     ...            ...                     ...   ...
# 49980  Laptop  Samsung   84929              8                      i9  12GB
# 49983  Laptop   Google  177919              2                 Ryzen 9   4GB
# 49990  Laptop   Google   99168              8                 Ryzen 9  32GB
# 49992  Laptop    Apple  156276             10                 Ryzen 3  12GB
# 49997  Laptop  Toshiba   66502              6                      i5   4GB
#
#          ROM    SSD
# 7      128GB  256GB
# ...

# %% [markdown]
# max ROM of the mobile

# %%
ml_max=ml['ROM'].max()
ml[(ml['ROM']==ml_max)&(ml['Product']=='Mobile Phone')][['Product','Brand','Price','ROM','RAM','Processor Specification']]
# Out:
#             Product     Brand   Price   ROM   RAM Processor Specification
# 9      Mobile Phone  Motorola  174698  64GB   6GB      MediaTek Dimensity
# 25     Mobile Phone    Realme  132523  64GB   8GB           Snapdragon 7s
# 35     Mobile Phone   Samsung   27749  64GB  32GB        Snapdragon 8 Gen
# 39     Mobile Phone      iQOO  107133  64GB   8GB        Snapdragon 7 Gen
# 48     Mobile Phone      Asus    9522  64GB   6GB          Apple A-Series
# ...             ...       ...     ...   ...   ...                     ...
# 49965  Mobile Phone   Toshiba  194689  64GB   6GB          MediaTek Helio
# 49979  Mobile Phone     Apple  143868  64GB   6GB      MediaTek Dimensity
# 49985  Mobile Phone      Asus   20144  64GB   8GB      MediaTek Dimensity
# 49991  Mobile Phone     Nokia  143290  64GB   4GB           Snapdragon 7s
# 49993  Mobile Phone  Motorola  159525  64GB   4GB          Apple A-Series
#
# [5043 rows x 6 columns]

# %% [markdown]
# max RAM of the mobile

# %%
ml_max_RAM=ml['RAM'].max()
ml[(ml['RAM']==ml_max_RAM)&(ml['Product']=='Mobile Phone')][['Product','Brand','Price','RAM','ROM','Processor Specification']]
# Out:
#             Product      Brand   Price  RAM    ROM Processor Specification
# 2      Mobile Phone    Samsung  159826  8GB  256GB      MediaTek Dimensity
# 25     Mobile Phone     Realme  132523  8GB   64GB           Snapdragon 7s
# 39     Mobile Phone       iQOO  107133  8GB   64GB        Snapdragon 7 Gen
# 65     Mobile Phone         HP   86484  8GB  128GB          MediaTek Helio
# 70     Mobile Phone   Motorola   47154  8GB   64GB           Snapdragon 7s
# ...             ...        ...     ...  ...    ...                     ...
# 49933  Mobile Phone   Motorola   56972  8GB  256GB          MediaTek Helio
# 49941  Mobile Phone      Nokia   61661  8GB    1TB      MediaTek Dimensity
# 49946  Mobile Phone     Realme   75811  8GB  256GB          Samsung Exynos
# 49957  Mobile Phone  Microsoft  105009  8GB  512GB          MediaTek Helio
# 49985  Mobile Phone       Asus   20144  8GB   64GB      MediaTek Dimensity
#
# [4171 rows x 6 columns]

# %%
a=ml.groupby('Product')
a

# %%
a.groups
# Out:
# {'Laptop': [1, 3, 4, 5, 7, 8, 13, 14, 19, 20, 21, 22, 23, 24, 26, 27, 28, 29, 31, 32, 41, 42, 43, 44, 45, 47, 51, 52, 55, 57, 58, 60, 61, 62, 64, 66, 68, 69, 72, 73, 76, 78, 79, 80, 81, 83, 85, 87, 89, 93, 94, 96, 97, 98, 99, 100, 102, 105, 106, 109, 113, 116, 117, 123, 124, 125, 127, 128, 129, 130, 132, 134, 135, 139, 140, 141, 144, 145, 146, 147, 148, 149, 152, 153, 154, 155, 166, 169, 171, 172, 173, 175, 176, 177, 179, 181, 182, 183, 188, 191, ...], 'Mobile Phone': [0, 2, 6, 9, 10, 11, 12, 15, 16, 17, 18, 25, 30, 33, 34, 35, 36, 37, 38, 39, 40, 46, 48, 49, 50, 53, 54, 56, 59, 63, 65, 67, 70, 71, 74, 75, 77, 82, 84, 86, 88, 90, 91, 92, 95, 101, 103, 104, 107, 108, 110, 111, 112, 114, 115, 118, 119, 120, 121, 122, 126, 131, 133, 136, 137, 138, 142, 143, 150, 151, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 167, 168, 170, 174, 178, 180, 184, 185, 186, 187, 189, 190, 193, 195, 197, 198, 199, 200, 201, 202, ...]}

# %%
p=ml['Price'].max()
ml[ml['Price']==p]
# Out:
#            Product Brand Product Code   Price  Quantity Sold  \
# 4620  Mobile Phone  Asus     5F4FA6DC  199999              1
#
#             Customer Name Customer Location Processor Specification  RAM  \
# 4620  Courtney Morgan DDS          Tranland          Samsung Exynos  8GB
#
#         ROM SSD
# 4620  256GB   0

# %%
x=mb['Brand']
y=mb['Price']

plt.xlabel('Brand')
plt.ylabel('Quantity Sold')
plt.bar(x,y)

plt.show()

# %%
mb
# Out:
#       Product    Brand   Price  Quantity Sold Processor Specification   RAM  \
# 7      Laptop    Apple   15041              1                      i7  12GB
# 8      Laptop    Apple  186647              3                      i5  16GB
# 13     Laptop    Nokia  195641             10                 Ryzen 3  12GB
# 23     Laptop    Nokia   55049              9                 Ryzen 3   8GB
# 28     Laptop  Samsung  133951              2                 Ryzen 3  16GB
# ...       ...      ...     ...            ...                     ...   ...
# 49980  Laptop  Samsung   84929              8                      i9  12GB
# 49983  Laptop   Google  177919              2                 Ryzen 9   4GB
# 49990  Laptop   Google   99168              8                 Ryzen 9  32GB
# 49992  Laptop    Apple  156276             10                 Ryzen 3  12GB
# 49997  Laptop  Toshiba   66502              6                      i5   4GB
#
#          ROM    SSD
# 7      128GB  256GB
# ...

# %%
mb['Product'].unique()
# Out:
# array(['Laptop'], dtype=object)

# %%
ml1=ml[ml['Brand']=='Apple'][['Price','Brand']]
ml1.shape
# Out:
# (2564, 2)

# %%
ml.describe().shape
# Out:
# (8, 2)

# %%
sns.heatmap(ml.describe())
plt.show()

# %%
ml
# Out:
#             Product      Brand Product Code   Price  Quantity Sold  \
# 0      Mobile Phone   Motorola     88EB4558   78570              6
# 1            Laptop       Oppo     416DFEEB   44613              1
# 2      Mobile Phone    Samsung     9F975B08  159826              5
# 3            Laptop       Sony     73D2A7CC   20911              1
# 4            Laptop  Microsoft     CCE0B80D   69832              4
# ...             ...        ...          ...     ...            ...
# 49995        Laptop   Motorola     8C187637  170385              6
# 49996        Laptop         HP     0DA9E4D3  193133              4
# 49997        Laptop    Toshiba     CAD89A93   66502              6
# 49998  Mobile Phone     Lenovo     78566C17  158883              2
# 49999        Laptop       Asus     9C3FC57C   86483              7
#
#            Customer Name      Customer Location Processor Specification   RAM  \
# 0           William Hess           South Kelsey        Snapdragon 7 Gen  12GB
# ...

# %%
ml.to_excel('/content/drive/MyDrive/data set/mobile_sales_data.xlsx',index=False)

# %%
ml
# Out:
#             Product      Brand Product Code   Price  Quantity Sold  \
# 0      Mobile Phone   Motorola     88EB4558   78570              6
# 1            Laptop       Oppo     416DFEEB   44613              1
# 2      Mobile Phone    Samsung     9F975B08  159826              5
# 3            Laptop       Sony     73D2A7CC   20911              1
# 4            Laptop  Microsoft     CCE0B80D   69832              4
# ...             ...        ...          ...     ...            ...
# 49995        Laptop   Motorola     8C187637  170385              6
# 49996        Laptop         HP     0DA9E4D3  193133              4
# 49997        Laptop    Toshiba     CAD89A93   66502              6
# 49998  Mobile Phone     Lenovo     78566C17  158883              2
# 49999        Laptop       Asus     9C3FC57C   86483              7
#
#            Customer Name      Customer Location Processor Specification   RAM  \
# 0           William Hess           South Kelsey        Snapdragon 7 Gen  12GB
# ...

# %%
ml=ml[ml['Product']!='Laptop']

# %%
ml.drop(['SSD','Customer Name','Customer Location','Product Code'],axis=1,inplace=True)
# Out:
# /tmp/ipython-input-4079933335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml.drop(['SSD','Customer Name','Customer Location','Product Code'],axis=1,inplace=True)

# %%
ml
# Out:
#             Product     Brand   Price  Quantity Sold Processor Specification  \
# 0      Mobile Phone  Motorola   78570              6        Snapdragon 7 Gen
# 2      Mobile Phone   Samsung  159826              5      MediaTek Dimensity
# 6      Mobile Phone      Dell   11670              6          Apple A-Series
# 9      Mobile Phone  Motorola  174698             10      MediaTek Dimensity
# 10     Mobile Phone     Apple   51251              9        Snapdragon 8 Gen
# ...             ...       ...     ...            ...                     ...
# 49984  Mobile Phone      iQOO  149619              5        Snapdragon 8 Gen
# 49985  Mobile Phone      Asus   20144              3      MediaTek Dimensity
# 49991  Mobile Phone     Nokia  143290              8           Snapdragon 7s
# 49993  Mobile Phone  Motorola  159525              8          Apple A-Series
# 49998  Mobile Phone    Lenovo  158883              2           Snapdragon 7s
#
#         RAM    ROM
# 0      12GB  128GB
# ...

# %%
ml=ml.reset_index(drop=True)

# %%
ml.to_excel('/content/drive/MyDrive/data set/mobile_sales_data.xlsx',index=False)

# %%
ml=ml[ml['Brand'].isin(['Google','Nokia','Apple','Samsung','Toshiba'])]

# %%
ml
# Out:
#             Product    Brand   Price  Quantity Sold Processor Specification  \
# 1      Mobile Phone  Samsung  159826              5      MediaTek Dimensity
# 4      Mobile Phone    Apple   51251              9        Snapdragon 8 Gen
# 5      Mobile Phone  Toshiba  179710              8           Snapdragon 7s
# 7      Mobile Phone  Samsung   57148              7          MediaTek Helio
# 9      Mobile Phone   Google   89801              9        Snapdragon 8 Gen
# ...             ...      ...     ...            ...                     ...
# 24960  Mobile Phone    Nokia   61661              4      MediaTek Dimensity
# 24965  Mobile Phone  Toshiba  142773              1        Snapdragon 7 Gen
# 24969  Mobile Phone  Toshiba  194689              3          MediaTek Helio
# 24975  Mobile Phone    Apple  143868              6      MediaTek Dimensity
# 24980  Mobile Phone    Nokia  143290              8           Snapdragon 7s
#
#         RAM    ROM
# 1       8GB  256GB
# ...

# %%
ml['Brand'].value_counts()
ml.pivot_table(values='Price',index='Brand',aggfunc=min)
# Out:
# /tmp/ipython-input-938952970.py:2: FutureWarning: The provided callable <built-in function min> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   ml.pivot_table(values='Price',index='Brand',aggfunc=min)
#          Price
# Brand
# Apple     5024
# Google    5250
# Nokia     5040
# Samsung   5182
# Toshiba   5437

# %%
sns.heatmap(ml.pivot_table(values='Price',index='Brand',aggfunc=min))
# Out:
# /tmp/ipython-input-2765726348.py:1: FutureWarning: The provided callable <built-in function min> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   sns.heatmap(ml.pivot_table(values='Price',index='Brand',aggfunc=min))
# <Axes: ylabel='Brand'>

# %%
ml.pivot_table(values='Brand',index='Quantity Sold',aggfunc=max)
# Out:
# /tmp/ipython-input-3962985936.py:1: FutureWarning: The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ml.pivot_table(values='Brand',index='Quantity Sold',aggfunc=max)
#                  Brand
# Quantity Sold
# 1              Toshiba
# 2              Toshiba
# 3              Toshiba
# 4              Toshiba
# 5              Toshiba
# 6              Toshiba
# 7              Toshiba
# 8              Toshiba
# 9              Toshiba
# 10             Toshiba
